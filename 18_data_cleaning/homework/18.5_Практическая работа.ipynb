# %% [markdown]
# # Разведочный анализ данных: Data Cleaning. Практическая работа

# %% [markdown]
# ## Цели практической работы
# * Потренироваться выявлять и заполнять пропущенные значения в данных.
# * Потренироваться преобразовывать типы данных.
# * Потренироваться выявлять и обрабатывать аномальные значения в данных.
# * Подготовить датафрейм к этапу генерации признаков.

# %% [markdown]
# ## Задача
#
# В этой практической работе вы продолжите исследовать и готовить данные для этапа моделирования: заполнять пропущенные значения в некоторых переменных, изменять типы данных и обрабатывать выбросы.
#
# Напомним, что вы работаете с небольшой выборкой из коллекции подержанных автомобилей, выставленных на продажу в Соединённых Штатах. На этих данных вы построите первую модель классификации, определяющую категорию цены подержанного автомобиля в зависимости от характеристик транспортного средства.
#
# ## Описание датасета:
# - `id`: идентификатор записи;
# - `url`: URL записи о продаже;
# - `region`: регион;
# - `region_url`: URL региона;
# - `price`: стоимость;
# - `year`: год выпуска;
# - `manufacturer`: производитель;
# - `model`: модель;
# - `condition`: состояние;
# - `cylinders`: количество цилиндров;
# - `fuel`: тип топлива;
# - `odometer`: количество пройденных миль;
# - `title_status`: статус;
# - `transmission`: коробка передач;
# - `VIN`: идентификационный номер;
# - `drive`: тип привода;
# - `size`: размер;
# - `type`: кузов;
# - `paint_color`: цвет;
# - `image_url`: URL изображения;
# - `description`: указанное описание;
# - `county`: страна;
# - `state`: штат;
# - `lat`: широта;
# - `long`: долгота;
# - `posting_date`: дата размещения объявления о продаже;
# - `price_category`: категория цены.

# %% [markdown]
# ## Что входит в практическую работу
# 1. Загрузить датасет и ознакомиться с ним.
# 2. Исследовать переменные датасета на наличие пропусков.
# 3. Обработать пропуски в зависимости от типа переменной.
# 4. Изменить типы данных.
# 5. Исследовать данные на аномальные значения и скорректировать выбросы.

# %% [markdown]
# ## Что оценивается
# - Программа выдаёт верный ответ на заданном наборе данных.
# - Описаны причины выбранного решения, если требуется.
# - Код читабелен: переменным даны осмысленные названия, отступы и правила расстановки пробелов соблюдены.
# - Репозиторий проекта содержит осмысленные коммиты с конкретными реализованными фичами, ветки названы согласно назначению, лишние файлы не хранятся в репозитории.
# - В репозитории проекта соблюдена иерархия директорий согласно списку модулей и содержащихся в них видеоматериалов.
# - Репозиторий проекта содержит файлы с данными, полученными в результате выполнения практической работы.

# %% [markdown]
# ## Как отправить работу на проверку
# Сдайте практическую работу этого модуля через систему контроля версий Git сервиса Skillbox GitLab. После загрузки работы на проверку напишите об этом в личном кабинете своему куратору.

# %% [markdown]
# ## Обязательные задачи

# %%
# Импортируйте необходимые библиотеки
import pandas as pd
import missingno as msno

# %% [markdown]
# ### Задача 1. Загрузка датасета и ознакомление с количеством пропущенных значений
#
# 1. Загрузите датасет из `data/df_out.csv` и выведите первые пять записей.

# %%
# Ваш код здесь
df = pd.read_csv('data/df_out.csv', index_col='id')
df.head(5)
# Out:
#                                                           url         region  \
# id
# 7308295377  https://chattanooga.craigslist.org/ctd/d/chatt...    chattanooga
# 7316380095  https://newjersey.craigslist.org/ctd/d/carlsta...   north jersey
# 7313733749  https://reno.craigslist.org/ctd/d/atlanta-2017...   reno / tahoe
# 7308210929  https://fayetteville.craigslist.org/ctd/d/rale...   fayetteville
# 7316474668  https://newyork.craigslist.org/lgi/cto/d/baldw...  new york city
#
#                                      region_url  price    year manufacturer  \
# id
# 7308295377   https://chattanooga.craigslist.org  54990  2020.0          ram
# 7316380095     https://newjersey.craigslist.org  16942  2016.0         ford
# 7313733749          https://reno.craigslist.org  35590  2017.0   volkswagen
# 7308210929  https://fayetteville.craigslist.org  14500  2013.0       toyota
# 7316474668       https://newyork.craigslist.org  21800  2021.0       nissan
#
#                              model    fuel  odometer title_status  \
# id
# 7308295377  2500 crew cab big horn  diesel     27442        clean
# 7316380095    explorer 4wd 4dr xlt     NaN     60023        clean
# 7313733749        golf r hatchback     gas     14048        clean
# 7308210929                    rav4     gas    117291        clean
# 7316474668                  altima     gas      8000        clean
#
#            transmission                                          image_url  \
# id
# 7308295377        other  https://images.craigslist.org/00N0N_1xMPvfxRAI...
# 7316380095    automatic  https://images.craigslist.org/00x0x_26jl9F0cnL...
# 7313733749        other  https://images.craigslist.org/00y0y_eeZjWeiSfb...
# 7308210929    automatic  https://images.craigslist.org/00606_iGe5iXidib...
# 7316474668    automatic  https://images.craigslist.org/00V0V_3pSOiPZ3Sd...
#
#                                                   description state  \
# id
# 7308295377  Carvana is the safer way to buy a car During t...    tn
# 7316380095  ***Call Us for more information at: 201-635-14...    nj
# 7313733749  Carvana is the safer way to buy a car During t...    ca
# 7308210929  2013 Toyota RAV4 XLE 4dr SUV     Offered by: R...    nc
# 7316474668  2021 Nissan Altima Sv with Only 8 K Miles Titl...    ny
#
#                   lat       long              posting_date price_category  \
# id
# 7308295377  35.060000 -85.250000  2021-04-17T12:30:50-0400           high
# 7316380095  40.821805 -74.061962  2021-05-03T15:40:21-0400         medium
# 7313733749  33.779214 -84.411811  2021-04-28T03:52:20-0700           high
# 7308210929  35.715954 -78.655304  2021-04-17T10:08:57-0400         medium
# 7316474668  40.654800 -73.609700  2021-05-03T18:32:06-0400         medium
#
#                                  date
# id
# 7308295377  2021-04-17 16:30:50+00:00
# 7316380095  2021-05-03 19:40:21+00:00
# 7313733749  2021-04-28 10:52:20+00:00
# 7308210929  2021-04-17 14:08:57+00:00
# 7316474668  2021-05-03 22:32:06+00:00

# %% [markdown]
# 2. Выведите информацию о датафрейме и обратите внимание на оставшиеся незаполненные значения.

# %%
# Ваш код здесь
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9902 entries, 7308295377 to 7311960763
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             9902 non-null   object
#  1   region          9902 non-null   object
#  2   region_url      9902 non-null   object
#  3   price           9902 non-null   int64
#  4   year            9868 non-null   float64
#  5   manufacturer    9902 non-null   object
#  6   model           9776 non-null   object
#  7   fuel            9841 non-null   object
#  8   odometer        9902 non-null   int64
#  9   title_status    9738 non-null   object
#  10  transmission    9902 non-null   object
#  11  image_url       9902 non-null   object
#  12  description     9902 non-null   object
#  13  state           9902 non-null   object
#  14  lat             9902 non-null   float64
#  15  long            9902 non-null   float64
#  16  posting_date    9902 non-null   object
#  17  price_category  9902 non-null   object
#  18  date            9902 non-null   object
# dtypes: float64(3), int64(2), object(14)
# memory usage: 1.5+ MB

# %% [markdown]
# 3. Выведите количество полностью заполненных объектов и их процент из всей выборки. Воспользуйтесь материалами из видео.

# %%
print(len(df.dropna()))
round(len(df.dropna()) / len(df) * 100, 2)
# Out:
# 9543
# 96.37

# %% [markdown]
# 4. Сохраните в переменную и выведите процент пропущенных значений для каждого признака, отсортируйте признаки по убыванию процента пропущенных значений. Воспользуйтесь материалами из видео и не забудьте передать верный параметр сортировки.

# %%
# Ваш код здесь
missing_values = ((df.isna().sum() / len(df)) * 100).sort_values(ascending=False)
missing_values
# Out:
# title_status      1.656231
# model             1.272470
# fuel              0.616037
# year              0.343365
# image_url         0.000000
# price_category    0.000000
# posting_date      0.000000
# long              0.000000
# lat               0.000000
# state             0.000000
# description       0.000000
# url               0.000000
# transmission      0.000000
# region            0.000000
# odometer          0.000000
# manufacturer      0.000000
# price             0.000000
# region_url        0.000000
# date              0.000000
# dtype: float64

# %% [markdown]
# 5. Выведите список всех признаков, в которых имеются пропущенные значения. Воспользуйтесь результатом вывода предыдущего задания, чтобы отсортировать признаки, подходящие под условие.

# %%
# Ваш код здесь
only_missing_values = missing_values[missing_values > 0]
only_missing_values
# Out:
# title_status    1.656231
# model           1.272470
# fuel            0.616037
# year            0.343365
# dtype: float64

# %% [markdown]
# ### Задача 2. Обработка пропусков в годе выпуска автомобиля
#
# 1. Выведите количество значений для года выпуска автомобиля, включая пропущенные значения.

# %%
# Ваш код здесь
df.year.value_counts(dropna=False)
# Out:
# 2017.0    808
# 2018.0    799
# 2016.0    733
# 2013.0    685
# 2015.0    664
#          ...
# 1927.0      1
# 1958.0      1
# 1941.0      1
# 1935.0      1
# 1954.0      1
# Name: year, Length: 90, dtype: int64

# %% [markdown]
# 2. Выведите количество пропущенных значений в годе выпуска автомобиля.

# %%
# Ваш код здесь
df.year.isna().sum()
# Out:
# 34

# %% [markdown]
# 3. Выведите описательные статистики для года выпуска автомобиля.

# %%
# Ваш код здесь
df.year.describe()
# Out:
# count    9868.000000
# mean     2010.909708
# std         9.705988
# min      1915.000000
# 25%      2008.000000
# 50%      2013.000000
# 75%      2017.000000
# max      2022.000000
# Name: year, dtype: float64

# %% [markdown]
# 4. Выведите записи, в которых год выпуска автомобиля не заполнен. Посмотрите на данные и подумайте, какую стратегию обработки значений можно применить.

# %%
# Ваш код здесь
df[df.year.isna()]
# Out:
#                                                           url  \
# id
# 7304102133  https://wenatchee.craigslist.org/ctd/d/wenatch...
# 7316337069  https://lasvegas.craigslist.org/ctd/d/scottsda...
# 7315662117  https://westslope.craigslist.org/ctd/d/denver-...
# 7316199009  https://nashville.craigslist.org/ctd/d/nashvil...
# 7316840794  https://denver.craigslist.org/ctd/d/american-f...
# 7311915616  https://westslope.craigslist.org/ctd/d/denver-...
# 7306735187  https://westslope.craigslist.org/ctd/d/denver-...
# 7309954650  https://gainesville.craigslist.org/ctd/d/gaine...
# 7313865045  https://westslope.craigslist.org/ctd/d/denver-...
# 7303344554  https://daytona.craigslist.org/ctd/d/new-smyrn...
# 7311762820  https://huntsville.craigslist.org/ctd/d/new-ca...
# 7315662074  https://santafe.craigslist.org/ctd/d/denver-20...
# 7314588156  https://inlandempire.craigslist.org/ctd/d/hesp...
# 7310250813  https://omaha.craigslist.org/ctd/d/council-blu...
# 7306678710  https://gainesville.craigslist.org/ctd/d/gaine...
# 7316562384  https://honolulu.craigslist.org/oah/ctd/d/hono...
# 7307209305  https://northmiss.craigslist.org/ctd/d/vicksbu...
# 7304711487  https://westslope.craigslist.org/ctd/d/denver-...
# 7309869204  https://scottsbluff.craigslist.org/ctd/d/denve...
# 7304693422  https://shreveport.craigslist.org/ctd/d/vicksb...
# 7310371320  https://westslope.craigslist.org/ctd/d/denver-...
# 7309904568  https://omaha.craigslist.org/ctd/d/omaha-2020-...
# 7315207437  https://huntsville.craigslist.org/ctd/d/new-ca...
# 7310924082  https://omaha.craigslist.org/ctd/d/omaha-2018-...
# 7316247218  https://lasvegas.craigslist.org/ctd/d/scottsda...
#
# 7311762820  29875   NaN        other               a Camry     gas     46947
# 7315662074  43900   NaN        other         Grand Caravan     NaN        21
# 7314588156   2599   NaN        other           olet Impala   other         1
# 7310250813  28995   NaN        other                 cadia     gas      3851
# 7306678710  26975   NaN        other              n Maxima     gas     28367
# 7316562384  37500   NaN        other        Grand Cherokee     NaN     26608
# 7307209305  64900   NaN        other                   500  diesel     12338
# 7304711487  67900   NaN        other               Odyssey     gas        21
# 7309869204  48900   NaN        other         Grand Caravan     NaN        19
# 7304693422  53700   NaN        other            ierra 1500     gas     35676
# 7310371320  49900   NaN        other               Enclave     gas     10345
# 7309904568  25399   NaN        other              Envision     NaN      8492
# 7315207437  35495   NaN        other                Series     gas     14000
# 7310924082  12995   NaN        other             u Impreza     gas     16740
# 7316247218  69995   NaN        other                 F-150     gas       412
# 7314898718  38975   NaN        other                   500     gas     28689
# 7314454466  49900   NaN        other              a Sienna     gas     34294
# 7310829676  83877   NaN        other          ierra 2500HD  diesel     25363
# 7316852999  19979   NaN        other                  CX-5     gas     17183
# 7316270709  49900   NaN        other              a Sienna     gas     34294
# 7312938642  67995   NaN        other   olet Silverado 1500     gas      7511
# 7309216259  29995   NaN        other               Enclave     gas      1036
# 7316246632  49995   NaN        other                   500     gas     19078
# 7314033574  54995   NaN        other                 F-150     gas       180
#
#            title_status transmission  \
# id
# 7304102133        clean    automatic
# 7316337069        clean    automatic
# 7315662117        clean    automatic
# 7316199009          NaN    automatic
# 7316840794        clean    automatic
# 7311915616        clean    automatic
# 7306735187        clean    automatic
# 7309954650        clean    automatic
# 7313865045        clean    automatic
# 7303344554        clean    automatic
# 7311762820        clean    automatic
# 7315662074        clean    automatic
# 7314588156        clean        other
# 7310250813          NaN    automatic
# 7306678710        clean    automatic
# 7316562384        clean    automatic
# 7307209305          NaN    automatic
# 7304711487        clean    automatic
# 7309869204        clean    automatic
# 7304693422          NaN    automatic
# 7310371320        clean    automatic
# 7309904568      rebuilt    automatic
# 7315207437        clean    automatic
# 7310924082      rebuilt    automatic
# 7316247218        clean    automatic
# 7314898718        clean    automatic
# 7314454466        clean    automatic
# 7310829676          NaN    automatic
# 7316852999        clean    automatic
# 7316270709        clean    automatic
# 7312938642        clean    automatic
# 7309216259      rebuilt    automatic
# 7316246632        clean    automatic
# 7314033574        clean    automatic
#
#                                                     image_url  \
# id
# 7304102133  https://images.craigslist.org/00J0J_6IMoEUzIIM...
# 7316337069  https://images.craigslist.org/00x0x_iQCC0Ef28S...
# 7315662117  https://images.craigslist.org/00f0f_7AwipNocNH...
# 7316199009  https://images.craigslist.org/00T0T_dZ7nOXskCS...
# 7316840794  https://images.craigslist.org/01616_bpzSdSRTbx...
# 7311915616  https://images.craigslist.org/00404_erlbeKWEkn...
# 7306735187  https://images.craigslist.org/00F0F_3T6FM0XMZW...
# 7309954650  https://images.craigslist.org/00000_2TUtAgLlCR...
# 7313865045  https://images.craigslist.org/00o0o_8XYp4Zygdj...
# 7303344554  https://images.craigslist.org/00a0a_d4XVrHnlxl...
# 7314349617  11976  2008.0        acura
#
#                                                 model fuel  odometer  \
# id
# 7316380095                       explorer 4wd 4dr xlt  NaN     60023
# 7309910590     camry solara 2dr cpe se v6 auto (natl)  NaN    193242
# 7314559074          f-150 4wd supercrew 145" platinum  NaN     79522
# 7315141987              frontier crew cab 4x2 sv auto  NaN     10679
# 7316807613    silverado 1500 ext cab 143.5" wb 4wd ls  NaN    172700
# 7314561306                    s-10 ext cab 123" wb ls  NaN     78740
# 7310297136                                      IC IC  NaN         0
# 7310414739               c-7500 multiple uses perfect  NaN     50098
# 7316342709  promaster cargo van 1500 low roof 118" wb  NaN     88836
# 7315151536           sienna le fwd 8-passenger (natl)  NaN     18762
# 7316383024       passat 4dr sdn 1.8t auto r-line pzev  NaN     54477
# 7314304193                 outlander sport es 2.0 cvt  NaN     25655
# 7302733118                                     fusion  NaN     95674
# 7314161453                                    journey  NaN     30273
# 7309203638                                      f-150  NaN     70927
# 7315330404                    escalade awd 4dr luxury  NaN    153932
# 7313525045                         altima 2.5 s sedan  NaN     42683
# 7310562680                          romeo stelvio awd  NaN     55645
# 7309460386                     cruze 4dr sdn auto 1lt  NaN     80859
# 7314857030                      civic sdn 4dr auto lx  NaN    140793
# 7314544641                     grand caravan se wagon  NaN     29982
# 7304158723                                sierra 1500  NaN    162934
# 7309551647                 renegade 4wd 4dr trailhawk  NaN     75314
# 7304419189              corolla 4dr sdn auto s (natl)  NaN    126872
# 7310520763                 g35 sedan g35 4dr sdn auto  NaN    140782
# 7308856751            2500 4dr quad cab 160.5 4wd slt  NaN    177001
# 7314143519               American LaFrance Fire Truck  NaN     78974
# 7311269192                                      focus  NaN     38505
# 7311631527                                   cherokee  NaN    103028
# 7312115428                         tiguan fwd 4dr sel  NaN    121515
# 7307388962                                 expedition  NaN    128975
# 7314750640                                  starcraft  NaN         0
# 7314282600                  odyssey 5dr touring elite  NaN    107176
# 7310526453                  xterra 4dr xe 2wd v6 auto  NaN    201570
# 7316686098                              cr-v ex-l awd  NaN     15392
# 7310551940   silverado 2500hd 4wd crew cab 153.7" ltz  NaN     50930
# 7314719321                                   versa sv  NaN     24140
# 7316456657           sonata 4dr sdn 2.4l auto limited  NaN    117773
# 7305971655                                    patriot  NaN     95674
# 7304094040                           INTERNATIONAL IC  NaN    134385
# 7314261064                                     taurus  NaN     49020
# 7315111002                    civic sdn 4dr auto ex-l  NaN     68522
# 7310860252                                  civic cpe  NaN     95674
# 7310766348                                      civic  NaN     95674
# 7305911263                             town & country  NaN    137312
# 7313584978                           elantra sel auto  NaN      8266
# 7310526393                               edge sel awd  NaN     89484
# 7314112375                      fusion 4dr sdn se fwd  NaN    111576
# 7308149122          challenger hellcat 6-speed manual  NaN      4697
# 7313576130          wrangler unlimited 4wd 4dr sahara  NaN    105927
# 7309365699                                      e-350  NaN    153120
# 7313475467                   equinox awd 4dr lt w/1lt  NaN    165554
# 7313949726                                     accord  NaN     95674
# 7314349617                                mdx 4wd 4dr  NaN    156801
#
#            title_status transmission  \
# id
# 7316380095        clean    automatic
# 7313949726  2021-04-28 18:25:32+00:00
# 7314349617  2021-04-29 16:05:16+00:00

# %% [markdown]
# 4. Обработайте пропуски, заполнив незаполненные значения типа топлива значением `other`, и сохраните изменения. Обратите внимание, что мы заполняем пропуски не самым популярным значением в выборке.

# %%
# Ваш код здесь
df_clean_fuel = df_clean.copy()
df_clean_fuel.fuel = df_clean.fuel.fillna('other')
df_clean = df_clean_fuel
### Именно здесь была ошибка пришлось делать дополнительный DF

# %% [markdown]
# 5. Выведите для обновлённого датафрейма количество пропущенных значений для типа топлива.

# %%
print("Количество пропущенных значений в fuel:", df_clean.fuel.isna().sum())   # Допишите код
print("Количество пропущенных значений в year:", df_clean.year.isna().sum())
# Out:
# Количество пропущенных значений в fuel: 0
# Количество пропущенных значений в year: 0

# %% [markdown]
# ### Задача 4. Обработка пропусков в модели автомобиля
#
# 1. Выведите количество значений для модели автомобиля, включая пропущенные значения. Обратите внимание на количество пропущенных значений.

# %%
# Ваш код здесь
df_clean.model.value_counts(dropna=False)
# Out:
# f-150                        148
# NaN                          126
# silverado 1500               106
# 1500                         100
# camry                         76
#                             ...
# sorrento lx v6                 1
# sierra1500 crewcab 4x4         1
# corolla se                     1
# xc60 t6 inscription sport      1
# a3 2.0t premium plus pzev      1
# Name: model, Length: 3438, dtype: int64

# %% [markdown]
# 2. Выведите описательные статистики для модели автомобиля.

# %%
# Ваш код здесь
df_clean.model.describe()
# Out:
# count      9742
# unique     3437
# top       f-150
# freq        148
# Name: model, dtype: object

# %% [markdown]
# 3. Выведите записи, в которых модель автомобиля не заполнена. Посмотрите на данные и подумайте, какую стратегию обработки значений можно применить.

# %%
# Ваш код здесь
df_clean[df_clean.model.isna()]
# Out:
#                                                           url  \
# id
# 7316913641  https://ventura.craigslist.org/cto/d/camarillo...
# 7316550853  https://chicago.craigslist.org/chc/cto/d/midlo...
# 7303575863  https://worcester.craigslist.org/ctd/d/fitchbu...
# 7315267860  https://gainesville.craigslist.org/ctd/d/kissi...
# 7316024407  https://reading.craigslist.org/ctd/d/paterson-...
# ...                                                       ...
# 7314341390  https://desmoines.craigslist.org/cto/d/urbanda...
# 7304358131  https://vermont.craigslist.org/ctd/d/salem-201...
# 7309686008  https://louisville.craigslist.org/cto/d/radcli...
# 7316447901  https://tulsa.craigslist.org/cto/d/tulsa-2017-...
# 7316458200  https://portland.craigslist.org/mlt/cto/d/port...
#
#                             region                          region_url  price  \
# id
# 7316913641          ventura county      https://ventura.craigslist.org   3000
# 7316550853                 chicago      https://chicago.craigslist.org   3000
# 7303575863  worcester / central MA    https://worcester.craigslist.org   7800
# 7315267860             gainesville  https://gainesville.craigslist.org  19200
# 7316024407                 reading      https://reading.craigslist.org  18695
# ...                            ...                                 ...    ...
# 7314341390              des moines    https://desmoines.craigslist.org   8000
# 7304358131                 vermont      https://vermont.craigslist.org  19944
# 7309686008              louisville   https://louisville.craigslist.org   1600
# 7316447901                   tulsa        https://tulsa.craigslist.org  65000
# 7316458200                portland     https://portland.craigslist.org  18500
#
#               year manufacturer model    fuel  odometer title_status  \
# id
# 7316913641  2005.0        rover   NaN     gas    165206        clean
# 7316550853  2006.0         jeep   NaN     gas    132000        clean
# 7303575863  2007.0          gmc   NaN     gas    190000        clean
# 7315267860  2012.0          ram   NaN     gas    121371        clean
# 7316024407  2007.0          ram   NaN  diesel    220019        clean
# ...            ...          ...   ...     ...       ...          ...
# 7314341390  2007.0       toyota   NaN     gas     85285        clean
# 7304358131  2012.0          ram   NaN     gas     73082        clean
# 7309686008  2005.0          gmc   NaN     gas     52536        clean
# 7316447901  2017.0        rover   NaN     gas     47000        clean
# 7316458200  1972.0    chevrolet   NaN     gas     75000        clean
#
#            transmission                                          image_url  \
# id
# 7316913641    automatic  https://images.craigslist.org/00S0S_b3yx6L4N2S...
# 7316550853    automatic  https://images.craigslist.org/01111_kNv3EKjH4H...
# 7303575863    automatic  https://images.craigslist.org/00f0f_iWjiToqea2...
# 7315267860    automatic  https://images.craigslist.org/00W0W_hHV4D0Po0G...
# 7316024407    automatic  https://images.craigslist.org/00n0n_jgq4eOvH7I...
# ...                 ...                                                ...
# 7314341390    automatic  https://images.craigslist.org/00K0K_aMoJgOIueB...
# 7304358131    automatic  https://images.craigslist.org/00A0A_bfCaGJ20IX...
# 7309686008    automatic  https://images.craigslist.org/01111_99unV6cYER...
# 7316447901    automatic  https://images.craigslist.org/00s0s_iGpmplDL99...
# 7316458200    automatic  https://images.craigslist.org/00x0x_7FqS8iHJst...
#
#                                                   description state  \
# id
# 7316913641  2005 Range Rover HSE  Changed Oil and now engi...    ca
# 7316550853  SUPER CLEAN 2006 JEEP LIBEERY RANAGADE  4X4  O...    il
# 7303575863  2007 gmc with plow leather loaded nice truck r...    ma
# 7315267860  2012 RAM 1500 Laramie Crew Cab 2WD     Offered...    fl
# 7316024407  2007 Dodge Ram 2500 SLT 4x4 Quad Cab Cummins D...    pa
# ...                                                       ...   ...
# 7314341390  Toyota has been owned by non smoker with no pe...    ia
# 7304358131  2012 RAM 1500 4WD REGULAR CAB SHORT BED 5.7 HE...    vt
# 7309686008  GMC Savana PRO AWD cargo van has been driven l...    ky
# 7316447901  2017 Range Rover HSE, supercharged V8, silver ...    ok
# 7316458200  1972 classic Chevrolet pick up custom  deluxe ...    or
#
#                   lat        long              posting_date price_category  \
# id
# 7316913641  34.219565 -119.001986  2021-05-04T13:11:15-0700            low
# 7316550853  41.618957  -87.726334  2021-05-03T20:33:40-0500            low
# 7303575863  42.579600  -71.803100  2021-04-08T09:10:07-0400            low
# 7315267860  28.329026  -81.404237  2021-05-01T10:05:17-0400         medium
# 7316024407  40.894535  -74.152367  2021-05-02T21:06:09-0400         medium
# ...               ...         ...                       ...            ...
# 7314341390  41.629500  -93.723000  2021-04-29T10:50:54-0500            low
# 7304358131  42.788204  -71.233728  2021-04-09T16:24:23-0400         medium
# 7309686008  37.858900  -86.006900  2021-04-20T04:48:30-0400            low
# 7316447901  36.126200  -95.940800  2021-05-03T16:37:36-0500           high
# 7316458200  45.494960 -122.666988  2021-05-03T14:58:34-0700         medium
#
#                                  date
# id
# 7316913641  2021-05-04 20:11:15+00:00
# 7316550853  2021-05-04 01:33:40+00:00
# 7303575863  2021-04-08 13:10:07+00:00
# 7315267860  2021-05-01 14:05:17+00:00
# 7316024407  2021-05-03 01:06:09+00:00
# ...                               ...
# 7314341390  2021-04-29 15:50:54+00:00
# 7304358131  2021-04-09 20:24:23+00:00
# 7309686008  2021-04-20 08:48:30+00:00
# 7316447901  2021-05-03 21:37:36+00:00
# 7316458200  2021-05-03 21:58:34+00:00
#
# [126 rows x 19 columns]

# %% [markdown]
# 4. Если подробнее изучить значения описания автомобиля, то, возможно, модель автомобиля получится восстановить из описания. Сейчас обработайте пропуски, заполнив незаполненные значения модели автомобиля значением `other`, и сохраните изменения. Обратите внимание, что мы в очередной раз заполняем пропуски не самым популярным значением в выборке.

# %%
# Ваш код здесь
df_clean.model = df_clean.model.fillna('other')

# %% [markdown]
# 5. Выведите для обновлённого датафрейма количество пропущенных значений для модели автомобиля.

# %%
print("Количество пропущенных значений в model:", df_clean.model.isna().sum())
print("Количество пропущенных значений в fuel:", df_clean.fuel.isna().sum())   # Допишите код
print("Количество пропущенных значений в year:", df_clean.year.isna().sum())
# Out:
# Количество пропущенных значений в model: 0
# Количество пропущенных значений в fuel: 0
# Количество пропущенных значений в year: 0

# %% [markdown]
# ### Задача 5. Обработка пропусков в статусе автомобиля
#
# 1. Выведите количество значений для статуса автомобиля, включая пропущенные значения. Обратите внимание на количество пропущенных значений.

# %%
# Ваш код здесь
df_clean.title_status.value_counts(dropna=False)
# Out:
# clean         9397
# rebuilt        168
# NaN            159
# salvage         91
# lien            35
# missing         16
# parts only       2
# Name: title_status, dtype: int64

# %% [markdown]
# 2. Выведите описательные статистики для модели автомобиля.

# %%
# Ваш код здесь
df_clean.title_status.describe()
# Out:
# count      9709
# unique        6
# top       clean
# freq       9397
# Name: title_status, dtype: object

# %% [markdown]
# 3. Выведите записи, в которых статус автомобиля не заполнен. Посмотрите на данные и подумайте, какую стратегию обработки значений можно применить.

# %%
# Ваш код здесь
df_clean[df_clean.title_status.isna()]
# Out:
#                                                           url  \
# id
# 7316540706  https://cincinnati.craigslist.org/ctd/d/fairfi...
# 7313570594  https://orangecounty.craigslist.org/ctd/d/coro...
# 7315211652  https://ocala.craigslist.org/ctd/d/riverview-2...
# 7306702976  https://toledo.craigslist.org/ctd/d/chelsea-73...
# 7307609203  https://roseburg.craigslist.org/ctd/d/eugene-2...
# ...                                                       ...
# 7301707830  https://tricities.craigslist.org/ctd/d/bristol...
# 7313949726  https://harrisburg.craigslist.org/ctd/d/brockp...
# 7314987181  https://nashville.craigslist.org/ctd/d/nashvil...
# 7309717260  https://savannah.craigslist.org/ctd/d/jacksonv...
# 7315557731  https://minneapolis.craigslist.org/csw/ctd/d/d...
#
#                            region                           region_url  price  \
# id
# 7316540706             cincinnati    https://cincinnati.craigslist.org   4995
# 7313570594          orange county  https://orangecounty.craigslist.org  17900
# 7315211652                  ocala         https://ocala.craigslist.org  40990
#
#                   lat        long              posting_date price_category  \
# id
# 7316540706  39.297045  -84.563243  2021-05-03T21:03:32-0400            low
# 7313570594  33.873436 -117.542806  2021-04-27T15:03:47-0700         medium
# 7315211652  27.849760  -82.364950  2021-05-01T06:35:56-0400           high
# 7306702976  42.300673  -84.024108  2021-04-14T12:03:01-0400            low
# 7307609203  44.058499 -123.106176  2021-04-16T04:06:29-0700         medium
# ...               ...         ...                       ...            ...
# 7301707830  36.541821  -82.234645  2021-04-04T13:12:27-0400            low
# 7313949726  41.261540  -78.704520  2021-04-28T14:25:32-0400            low
# 7314987181  36.138022  -86.732261  2021-04-30T15:00:48-0500         medium
# 7309717260  30.513566  -81.621875  2021-04-20T08:01:49-0400         medium
# 7315557731  45.082884  -94.334760  2021-05-01T18:03:06-0500           high
#
#                                  date
# id
# 7316540706  2021-05-04 01:03:32+00:00
# 7313570594  2021-04-27 22:03:47+00:00
# 7315211652  2021-05-01 10:35:56+00:00
# 7306702976  2021-04-14 16:03:01+00:00
# 7307609203  2021-04-16 11:06:29+00:00
# ...                               ...
# 7301707830  2021-04-04 17:12:27+00:00
# 7313949726  2021-04-28 18:25:32+00:00
# 7314987181  2021-04-30 20:00:48+00:00
# 7309717260  2021-04-20 12:01:49+00:00
# 7315557731  2021-05-01 23:03:06+00:00
#
# [159 rows x 19 columns]

# %% [markdown]
# 4. Обработайте пропуски, заполнив незаполненные значения статуса автомобиля самым популярным значением, и сохраните изменения. Самое популярное значение передайте не в виде строки, а получите моду.

# %%
# Ваш код здесь
most_common_status = df_clean.title_status.mode()[0]
df_clean.title_status = df_clean.title_status.fillna(most_common_status)

# %% [markdown]
# 5. Выведите для обновлённого датафрейма количество пропущенных значений для статуса автомобиля.

# %%
print("Количество пропущенных значений в title_status:", df_clean.title_status.isna().sum())
print("Количество пропущенных значений в model:", df_clean.model.isna().sum())
print("Количество пропущенных значений в fuel:", df_clean.fuel.isna().sum())   # Допишите код
print("Количество пропущенных значений в year:", df_clean.year.isna().sum())
# Out:
# Количество пропущенных значений в title_status: 0
# Количество пропущенных значений в model: 0
# Количество пропущенных значений в fuel: 0
# Количество пропущенных значений в year: 0

# %% [markdown]
# 6. Ещё раз выведите количество полностью заполненных объектов и их процент из всей выборки. После обработки всех пропусков можно переходить к следующему этапу.

# %%
# Ваш код здесь
missing_values_after = ((df_clean.isna().sum() / len(df)) * 100).sort_values(ascending=False)
missing_values_after
# Out:
# url               0.0
# transmission      0.0
# price_category    0.0
# posting_date      0.0
# long              0.0
# lat               0.0
# state             0.0
# description       0.0
# image_url         0.0
# title_status      0.0
# region            0.0
# odometer          0.0
# fuel              0.0
# model             0.0
# manufacturer      0.0
# year              0.0
# price             0.0
# region_url        0.0
# date              0.0
# dtype: float64

# %% [markdown]
# ### Задача 6. Преобразование типа данных в годе выпуска автомобиля
# 1.  Выведите информацию о датафрейме и обратите внимание на типы данных.

# %%
# Ваш код здесь
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9868 entries, 7308295377 to 7311960763
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             9868 non-null   object
#  1   region          9868 non-null   object
#  2   region_url      9868 non-null   object
#  3   price           9868 non-null   int64
#  4   year            9868 non-null   float64
#  5   manufacturer    9868 non-null   object
#  6   model           9868 non-null   object
#  7   fuel            9868 non-null   object
#  8   odometer        9868 non-null   int64
#  9   title_status    9868 non-null   object
#  10  transmission    9868 non-null   object
#  11  image_url       9868 non-null   object
#  12  description     9868 non-null   object
#  13  state           9868 non-null   object
#  14  lat             9868 non-null   float64
#  15  long            9868 non-null   float64
#  16  posting_date    9868 non-null   object
#  17  price_category  9868 non-null   object
#  18  date            9868 non-null   object
# dtypes: float64(3), int64(2), object(14)
# memory usage: 1.5+ MB

# %% [markdown]
# 2. Выведите описательные статистики для года выпуска автомобиля. Обратите внимание на тип данных.

# %%
# Ваш код здесь
df_clean.year.describe()
# Out:
# count    9868.000000
# mean     2010.909708
# std         9.705988
# min      1915.000000
# 25%      2008.000000
# 50%      2013.000000
# 75%      2017.000000
# max      2022.000000
# Name: year, dtype: float64

# %% [markdown]
# 3. Измените тип данных для года выпуска на более подходящий целочисленный тип и выведите получившийся тип данных только для года выпуска.

# %%
# Ваш код здесь
df_clean.year = df_clean.year.astype(int)
df_clean.year.dtypes
# Out:
# dtype('int32')

# %% [markdown]
# ### Задача 7. Преобразование типа данных в категориальных переменных
#
# 1. Выведите тип данных для типа топлива автомобиля.

# %%
# Ваш код здесь
df_clean.fuel.dtypes
# Out:
# dtype('O')

# %% [markdown]
# 2. Категориальным переменным можно задавать специальный тип данных `category`. Подробнее об этом можно прочитать в [документации](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html). Укажите для типа топлива тип данных `category`, сохраните изменения в переменную `series` и выведите её.

# %%
# Ваш код здесь
series = df_clean.fuel.astype('category')
series
# Out:
# id
# 7308295377    diesel
# 7316380095     other
# 7313733749       gas
# 7308210929       gas
# 7316474668       gas
#                ...
# 7304876387       gas
# 7316152972       gas
# 7310993818       gas
# 7306637427    hybrid
# 7311960763       gas
# Name: fuel, Length: 9868, dtype: category
# Categories (5, object): ['diesel', 'electric', 'gas', 'hybrid', 'other']

# %% [markdown]
# 3. Выведите тип данных для серии. Обратите внимание на структуру вывода.

# %%
# Ваш код здесь
series.dtypes.categories
# Out:
# Index(['diesel', 'electric', 'gas', 'hybrid', 'other'], dtype='object')

# %% [markdown]
# 4. Выведите первые две категории, используя вывод типа данных выше.

# %%
# Ваш код здесь
series.dtypes.categories[:2]
# Out:
# Index(['diesel', 'electric'], dtype='object')

# %% [markdown]
# ### Задача 8. Выбросы в годе выпуска
#
# 1. Выведите описательные статистики для года выпуска автомобиля. Обратите внимание на пограничные значения, на квартили.

# %%
# Ваш код здесь
df_clean.year.describe()
# Out:
# count    9868.000000
# mean     2010.909708
# std         9.705988
# min      1915.000000
# 25%      2008.000000
# 50%      2013.000000
# 75%      2017.000000
# max      2022.000000
# Name: year, dtype: float64

# %% [markdown]
# 2. Выведите границы для нормальных значений года выпуска, используя интерквартильный размах. Воспользуйтесь материалами из видео. Посмотрите, входят ли минимальное и максимальное значения в интервал между полученными границами.

# %%
# Ваш код здесь
q25 = df_clean.year.quantile(0.25)
q75 = df_clean.year.quantile(0.75)
iqr = q75 - q25
boundaries = (q25 - 1.5 * iqr, q75 + 1.5 * iqr)
boundaries
# Out:
# (1994.5, 2030.5)

# %% [markdown]
# 3. Посчитайте и выведите количество выбросов в годе выпуска автомобиля.

# %%
# Ваш код здесь
is_outlier = (df_clean.year < boundaries[0]) | (df_clean.year > boundaries[1])
is_outlier.sum()
# Out:
# 394

# %% [markdown]
# 4. Посчитайте и выведите долю выбросов в годе выпуска автомобиля.

# %%
# Ваш код здесь
is_outlier.sum() / len(df_clean.year)
# Out:
# 0.03992703688690717

# %% [markdown]
# 5. Выведите записи, в которых год выпуска попадает в выбросы. Посмотрите на данные и подумайте, могут ли эти выбросы описывать особые значения категории цены или других признаков или действительно являются выбросами.

# %%
# Ваш код здесь
df_clean[is_outlier]
### Некоторые старые автомобили могут влиять на цену, так как явяляются раритетными и коллекционными
# Out:
#                                                           url  \
# id
# 7317089086  https://seattle.craigslist.org/see/ctd/d/portl...
# 7312327909  https://madison.craigslist.org/cto/d/madison-1...
# 7314413105  https://inlandempire.craigslist.org/ctd/d/cost...
# 7310077530  https://hudsonvalley.craigslist.org/cto/d/bloo...
# 7314527175  https://rapidcity.craigslist.org/ctd/d/sherman...
# ...                                                       ...
# 7313487583  https://springfield.craigslist.org/cto/d/mount...
# 7311566144  https://chico.craigslist.org/cto/d/chico-1994-...
# 7313676859  https://reno.craigslist.org/ctd/d/sherman-1984...
# 7316458200  https://portland.craigslist.org/mlt/cto/d/port...
# 7316175335  https://orangecounty.craigslist.org/cto/d/hunt...
#
#                           region                           region_url  price  \
# id
# 7317089086        seattle-tacoma       https://seattle.craigslist.org  14995
# 7312327909               madison       https://madison.craigslist.org  89995
# 7314413105         inland empire  https://inlandempire.craigslist.org  69888
# 7310077530         hudson valley  https://hudsonvalley.craigslist.org   5500
# 7314527175  rapid city / west SD     https://rapidcity.craigslist.org  43500
# ...                          ...                                  ...    ...
# 7313487583           springfield   https://springfield.craigslist.org   3500
# 7311566144                 chico         https://chico.craigslist.org  16000
# 7313676859          reno / tahoe          https://reno.craigslist.org  26500
# 7316458200              portland      https://portland.craigslist.org  18500
# 7316175335         orange county  https://orangecounty.craigslist.org   1575
#
#             year manufacturer  \
# id
# 7317089086  1994         ford
# 7312327909  1970        other
# 7314413105  1948         ford
# 7310077530  1990        other
# 7314527175  1968    chevrolet
# ...          ...          ...
# 7313487583  1974         jeep
# 7311566144  1994         ford
# 7313676859  1984    chevrolet
# 7316458200  1972    chevrolet
# 7316175335  1988        other
#
#                                                         model fuel  odometer  \
# id
# 7317089086  e-series van universal by glaval designer luxu...  gas    156925
# 7312327909                                     oldsmobile 442  gas    111111
# 7314413105                                                coe  gas         1
# 7310077530                                           Diahatsu  gas     30000
# 7314527175                                             camaro  gas     43320
# ...                                                       ...  ...       ...
# 7313487583                                                cj5  gas     10000
# 7311566144                                               f250  gas     32500
# 7313676859                                          silverado  gas     38751
# 7316458200                                              other  gas     75000
# 7316175335                                         1988 Nisan  gas    120000
#
#            title_status transmission  \
# id
# 7317089086        clean    automatic
# 7312327909        clean    automatic
# 7314413105        clean    automatic
# 7310077530        clean       manual
# 7314527175        clean       manual
# ...                 ...          ...
# 7313487583        clean       manual
# 7311566144        clean    automatic
# %%
# Ваш код здесь
df_clean[is_outlier].price.value_counts()
# Out:
# 10000    13
# 5000     13
# 25000    11
# 9500     10
# 2500      8
#          ..
# 13200     1
# 19000     1
# 39995     1
# 3499      1
# 1575      1
# Name: price, Length: 176, dtype: int64

# %% [markdown]
# 7. Так как выбросы в годе выпуска находятся среди минимальных значений, заполните те значения, которые являются выбросами, значением нижней границы. Не забудьте учесть, что год должен быть целочисленным значением, входящим в границы нормальных значений.

# %%
# Ваш код здесь
df_clean.loc[is_outlier, 'year'] = int(boundaries[0])

# %% [markdown]
# 8. Выведите ещё раз описательные статистики для года выпуска автомобиля, чтобы проверить, что теперь все значения года входят в границы нормальных значений.

# %%
# Ваш код здесь
df_clean.year.describe()
### Теперь все значения входят в границы но так как по заданию надо было целое число, 
### то все равно выдает что 394 машины не входят в границы, так как граница 1994.5
# Out:
# count    9868.000000
# mean     2011.658391
# std         6.530991
# min      1994.000000
# 25%      2008.000000
# 50%      2013.000000
# 75%      2017.000000
# max      2022.000000
# Name: year, dtype: float64

# %% [markdown]
# ## Дополнительные задачи

# %% [markdown]
# ### Задача 9. Загрузка датафрейма с параметрами преобразования
#
# Некоторые преобразования признаков можно сделать ещё в момент загрузки датафрейма из файла.
#
# 1. Прочитайте в новый датафрейм файл `data/vehicles_dataset.csv`, выбрав только нужные колонки и применив приведение типов данных. Обратитесь к [документации](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html), чтобы узнать, за что отвечают параметры `usecols`,  `parse_dates` и `dtype`.
#
#
# Датафрейм должен содержать:
# - колонки `price`, `year`, `posting_date`;
# - `posting_date` в datatime-формате;
# - `price` в вещественном формате;
# - `year` в целочисленном формате.
#
# Возможно, вы столкнётесь с ошибкой при считывании года в виде целого числа. Подробнее о том, как бороться с этой ошибкой, можно узнать в документации по `обнуляемому целочисленному типу данных`:
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/integer_na.html
#
# *Подсказка:* Pandas может представлять целочисленные данные с возможными отсутствующими значениями, используя [arrays.IntegerArray](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.arrays.IntegerArray.html#pandas.arrays.IntegerArray) или его псевдонимы, которые вы сможете найти в документации.

# %%
# Ваш код здесь
selected_columns = ["price", "year", "posting_date"]
data = pd.read_csv("data/vehicles_dataset.csv", usecols = selected_columns, parse_dates=["posting_date"])
data.price = data.price.astype(float)
data.year = data.year.astype('Int32')
print(data.head())
# Out:
#      price  year               posting_date
# 0  54990.0  2020  2021-04-17 12:30:50-04:00
# 1  16942.0  2016  2021-05-03 15:40:21-04:00
# 2  35590.0  2017  2021-04-28 03:52:20-07:00
# 3  14500.0  2013  2021-04-17 10:08:57-04:00
# 4  21800.0  2021  2021-05-03 18:32:06-04:00

# %% [markdown]
# 2. Выведите информацию о датафрейме, чтобы убедиться, что признаки при загрузке преобразовались верно.

# %%
# Ваш код здесь
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10050 entries, 0 to 10049
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         10050 non-null  float64
#  1   year          10014 non-null  Int32
#  2   posting_date  10048 non-null  object
# dtypes: Int32(1), float64(1), object(1)
# memory usage: 206.2+ KB

# %% [markdown]
# 3. Для первой записи в датафрейме извлеките из `posting_date` и выведите номер месяца.

# %%
# Ваш код здесь
data.posting_date.iloc[0].month
# Out:
# 4
